# %% [markdown]
# #Dataset Description

# %% [markdown]
# \
#
# ## The dataset contains information about road traffic accidents with the following columns:
#
# `Time`: Time of the accident
#
# `Day_of_week`: Day of the week when the accident occurred
#
# `Age_band_of_driver`: Age group of the driver
#
# `Sex_of_driver`: Gender of the driver
#
# `Educational_level`: Educational level of the driver
#
# `Vehicle_driver_relation`: Relationship of the driver to the vehicle
#
# `Driving_experience`: Driving experience of the driver
#
# `Type_of_vehicle`: Type of vehicle involved in the accident
#
# `Owner_of_vehicle`: Owner of the vehicle
#
# `Service_year_of_vehicle`: Service years of the vehicle
#
# `Area_accident_occured`: Area where the accident occurred
#
# `Lanes_or_Medians`: Lanes or medians at the accident site
#
# `Road_allignment`: Road alignment at the accident site
#
# `Types_of_Junction`: Type of junction at the accident site
#
# `Road_surface_type`: Type of road surface at the accident site
#
# `Road_surface_conditions`: Road surface conditions at the accident site
#
# `Light_conditions`: Light conditions at the time of the accident
#
# `Weather_conditions`: Weather conditions at the time of the accident
#
# `Type_of_collision`: Type of collision
#
# `Number_of_vehicles_involved`: Number of vehicles involved in the accident
#
# `Number_of_casualties`: Number of casualties in the accident
#
# `Vehicle_movement`: Movement of the vehicle during the accident
#
# `Casualty_class`: Class of casualty (driver, passenger, pedestrian)
#
# `Sex_of_casualty`: Gender of the casualty
#
# `Age_band_of_casualty`: Age group of the casualty
#
# `Casualty_severity`: Severity of the casualty
#
# `Work_of_casuality`: Occupation of the casualty
#
# `Fitness_of_casuality`: Fitness of the casualty
#
# `Pedestrian_movement`: Movement of the pedestrian
#
# `Cause_of_accident`: Cause of the accident
#
# `Accident_severity`: Severity of the accident

# %% [markdown]
# # Tasks

# %% [markdown]
# ##1. Data Cleaning

# %% [markdown]
# ### Read the dataset

# %%
import pandas as pd
df=pd.read_csv('/content/Task (1) Dataset.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  object
#  1   Day_of_week                  12316 non-null  object
#  2   Age_band_of_driver           12316 non-null  object
#  3   Sex_of_driver                12316 non-null  object
#  4   Educational_level            11575 non-null  object
#  5   Vehicle_driver_relation      11737 non-null  object
#  6   Driving_experience           11487 non-null  object
#  7   Type_of_vehicle              11366 non-null  object
#  8   Owner_of_vehicle             11834 non-null  object
#  9   Service_year_of_vehicle      8388 non-null   object
#  10  Defect_of_vehicle            7889 non-null   object
#  11  Area_accident_occured        12077 non-null  object
#  12  Lanes_or_Medians             11931 non-null  object
# ...

# %%
df
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 0       Above high school                Employee              1-2yr
# 1      Junior high school                Employee         Above 10yr
# ...

# %% [markdown]
# ### Handle Missing Values

# %%
df.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %%
df.sample()
# Out:
#         Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 450  9:05:00      Monday              31-50          Male  Junior high school
#
#     Vehicle_driver_relation Driving_experience Type_of_vehicle  \
# 450                Employee         Above 10yr           Other
#
#     Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# 450            Owner                 Unknown  ...   Going straight
#
#     Casualty_class Sex_of_casualty Age_band_of_casualty Casualty_severity  \
# 450     Pedestrian          Female                31-50                 3
#
#     Work_of_casuality Fitness_of_casuality              Pedestrian_movement  \
# 450            Driver               Normal  Crossing from driver's nearside
#
#              Cause_of_accident Accident_severity
# 450  Changing lane to the left     Slight Injury
#
# [1 rows x 32 columns]

# %%
df=df.drop(['Fitness_of_casuality','Work_of_casuality','Defect_of_vehicle','Service_year_of_vehicle'],axis=1)
df
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 0       Above high school                Employee              1-2yr
# 1      Junior high school                Employee         Above 10yr
# ...

# %%
df.dropna(subset=['Type_of_collision', 'Vehicle_movement', 'Road_surface_type', 'Road_allignment', 'Area_accident_occured'], inplace=True)
df
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# 7      17:20:00      Friday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 0       Above high school                Employee              1-2yr
# 1      Junior high school                Employee         Above 10yr
# ...

# %%
df.dropna(subset=['Lanes_or_Medians'], inplace=True)

# %%
df.dropna(subset=['Area_accident_occured', 'Owner_of_vehicle'], inplace=True)
df
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 1      17:02:00      Monday              31-50          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# 7      17:20:00      Friday              18-30          Male
# 8      17:20:00      Friday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 1      Junior high school                Employee         Above 10yr
# 3      Junior high school                Employee             5-10yr
# ...

# %%
for column in ['Educational_level', 'Vehicle_driver_relation', 'Driving_experience', 'Type_of_vehicle', 'Types_of_Junction']:
  mode_value = df[column].mode()[0]
  df[column].fillna(mode_value, inplace=True)
df
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 1      17:02:00      Monday              31-50          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# 7      17:20:00      Friday              18-30          Male
# 8      17:20:00      Friday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 1      Junior high school                Employee         Above 10yr
# 3      Junior high school                Employee             5-10yr
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10706 entries, 1 to 12315
# Data columns (total 28 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         10706 non-null  object
#  1   Day_of_week                  10706 non-null  object
#  2   Age_band_of_driver           10706 non-null  object
#  3   Sex_of_driver                10706 non-null  object
#  4   Educational_level            10706 non-null  object
#  5   Vehicle_driver_relation      10706 non-null  object
#  6   Driving_experience           10706 non-null  object
#  7   Type_of_vehicle              10706 non-null  object
#  8   Owner_of_vehicle             10706 non-null  object
#  9   Area_accident_occured        10706 non-null  object
#  10  Lanes_or_Medians             10706 non-null  object
#  11  Road_allignment              10706 non-null  object
#  12  Types_of_Junction            10706 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# Time                           0
# Day_of_week                    0
# Age_band_of_driver             0
# Sex_of_driver                  0
# Educational_level              0
# Vehicle_driver_relation        0
# Driving_experience             0
# Type_of_vehicle                0
# Owner_of_vehicle               0
# Area_accident_occured          0
# Lanes_or_Medians               0
# Road_allignment                0
# Types_of_Junction              0
# Road_surface_type              0
# Road_surface_conditions        0
# Light_conditions               0
# Weather_conditions             0
# Type_of_collision              0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Vehicle_movement               0
# Casualty_class                 0
# Sex_of_casualty                0
# Age_band_of_casualty           0
# Casualty_severity              0
# Pedestrian_movement            0
# Cause_of_accident              0
# Accident_severity              0
# dtype: int64

# %% [markdown]
# ### Correct any inconsistent data entries.

# %%
df['Accident_severity'] = df['Accident_severity'].replace({'Slight Injury': 'Slight injury'})
df
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 1      17:02:00      Monday              31-50          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# 7      17:20:00      Friday              18-30          Male
# 8      17:20:00      Friday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 1      Junior high school                Employee         Above 10yr
# 3      Junior high school                Employee             5-10yr
# ...

# %% [markdown]
# ### Ensure data types are appropriate for each column.
#
# ---

# %%
df['Time'] = pd.to_datetime(df['Time'])
# Out:
# <ipython-input-13-1bfd8981fe14>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Time'] = pd.to_datetime(df['Time'])

# %%
df['Day_of_week'] = df['Day_of_week'].astype('category')
df['Age_band_of_driver'] = df['Age_band_of_driver'].astype('category')
df['Sex_of_driver'] = df['Sex_of_driver'].astype('category')
df['Educational_level'] = df['Educational_level'].astype('category')
df['Vehicle_driver_relation'] = df['Vehicle_driver_relation'].astype('category')
df['Driving_experience'] = df['Driving_experience'].astype('category')
df['Type_of_vehicle'] = df['Type_of_vehicle'].astype('category')
df['Owner_of_vehicle'] = df['Owner_of_vehicle'].astype('category')
df['Area_accident_occured'] = df['Area_accident_occured'].astype('category')
df['Lanes_or_Medians'] = df['Lanes_or_Medians'].astype('category')
df['Road_allignment'] = df['Road_allignment'].astype('category')
df['Types_of_Junction'] = df['Types_of_Junction'].astype('category')
df['Road_surface_type'] = df['Road_surface_type'].astype('category')
df['Road_surface_conditions'] = df['Road_surface_conditions'].astype('category')
df['Light_conditions'] = df['Light_conditions'].astype('category')
df['Weather_conditions'] = df['Weather_conditions'].astype('category')
df['Type_of_collision'] = df['Type_of_collision'].astype('category')
df['Vehicle_movement'] = df['Vehicle_movement'].astype('category')
df['Casualty_class'] = df['Casualty_class'].astype('category')
df['Sex_of_casualty'] = df['Sex_of_casualty'].astype('category')
df['Age_band_of_casualty'] = df['Age_band_of_casualty'].astype('category')
df['Casualty_severity'] = df['Casualty_severity'].astype('category')
df['Pedestrian_movement'] = df['Pedestrian_movement'].astype('category')
df['Cause_of_accident'] = df['Cause_of_accident'].astype('category')
df['Accident_severity'] = df['Accident_severity'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10706 entries, 1 to 12315
# Data columns (total 28 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         10706 non-null  datetime64[ns]
#  1   Day_of_week                  10706 non-null  category
#  2   Age_band_of_driver           10706 non-null  category
#  3   Sex_of_driver                10706 non-null  category
#  4   Educational_level            10706 non-null  category
#  5   Vehicle_driver_relation      10706 non-null  category
#  6   Driving_experience           10706 non-null  category
#  7   Type_of_vehicle              10706 non-null  category
#  8   Owner_of_vehicle             10706 non-null  category
#  9   Area_accident_occured        10706 non-null  category
#  10  Lanes_or_Medians             10706 non-null  category
#  11  Road_allignment              10706 non-null  category
# ...

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
df.describe()
# Out:
#                                 Time  Number_of_vehicles_involved  \
# count                          10706                 10706.000000
# mean   2024-07-25 14:17:19.273304832                     2.041098
# min              2024-07-25 00:01:00                     1.000000
# 25%              2024-07-25 10:30:00                     2.000000
# 50%              2024-07-25 15:10:00                     2.000000
# 75%              2024-07-25 18:10:00                     2.000000
# max              2024-07-25 23:59:00                     7.000000
# std                              NaN                     0.689409
#
#        Number_of_casualties
# count          10706.000000
# mean               1.549412
# min                1.000000
# 25%                1.000000
# 50%                1.000000
# 75%                2.000000
# max                8.000000
# std                1.010009

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

accident_severity_by_day = df.groupby('Day_of_week')['Accident_severity'].value_counts(normalize=True).unstack()
accident_severity_by_day.plot(kind='bar', stacked=True)
plt.title('Accident Severity by Day of the Week')
plt.xlabel('Day of the Week')
plt.ylabel('Proportion of Accidents')
plt.show()

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Age_band_of_driver, Type_of_vehicle).

# %%
plt.figure(figsize=(7, 6))
sns.countplot(x='Age_band_of_driver', data=df)
plt.title('Distribution of Age Band of Driver')
plt.xlabel('Age Band of Driver')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(7, 6))
sns.countplot(x='Type_of_vehicle', data=df)
plt.title('Distribution of Type of Vehicle')
plt.xlabel('Type of Vehicle')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Explore relationships between variables (e.g., Age_band_of_driver vs. Accident_severity).

# %%
accident_severity_by_age = df.groupby('Age_band_of_driver')['Accident_severity'].value_counts(normalize=True).unstack()
accident_severity_by_age.plot(kind='bar', stacked=True)
plt.title('Accident Severity by Age')
plt.xlabel('Age Band of Drive')
plt.ylabel('Proportion of Accidents')
plt.show()

# %%
pokemon = pd.DataFrame(df)

pokemon.plot.scatter(x='Age_band_of_driver', y='Accident_severity', title="'Accident Severity by Age Band of Driver'")

plt.show()

# %% [markdown]
# ## 3. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %%
pokemon = pd.DataFrame(df)

pokemon.plot.hexbin(x='Number_of_vehicles_involved', y='Number_of_casualties', title="hixbin Plot of Age band of driver vs Number of casualties" , gridsize=15)

plt.show()

# %%
df.plot.scatter(x='Age_band_of_driver', y='Accident_severity', c='Number_of_casualties', cmap='viridis')
# Out:
# <Axes: xlabel='Age_band_of_driver', ylabel='Accident_severity'>

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Driving_experience', y='Number_of_casualties', data=df)
plt.title('Relationship between Driving Experience and Number of Casualties')
plt.xlabel('Driving Experience')
plt.ylabel('Number of Casualties')
plt.show()

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %%
cause_counts = df['Cause_of_accident'].value_counts()
plt.figure(figsize=(8, 10))
plt.pie(cause_counts, labels=cause_counts.index, autopct='%1.1f%%', startangle=45)
plt.title('Distribution of Causes of Accidents')
plt.show()

# %%
import numpy as np
plt.figure(figsize=(12, 10))
sns.heatmap(df.corr(), annot=True )
plt.title('Correlation Matrix of Accident Factors')
plt.show()

# %% [markdown]
# ## 4. Insights and Conclusions

# %% [markdown]
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>

# %% [markdown]
# Most accidents result in slight injuries, followed by serious injuries and fatalities. Weekdays are less accident-prone than weekends. Injuries to younger drivers are more severe than those to older drivers.
# Drivers with less experience are more likely to crash. It is believed that certain vehicle types are associated with accident severity. No distancing is the top accident cause, underscoring the importance of safe driving.
